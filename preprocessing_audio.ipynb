# %%
# %matplotlib inline

# %% [markdown]
# # Convert audio into .wav file

# %% [markdown]
# This module can use for converting audio file in original dataset. After you get the original audio, you can generate more noise audio if you like. The noise audio dataset create way is showed on our website. We provide some exmaple noise audio in github.

# %%
# -*- coding: utf-8 -*-
""" Convert audio into .wav file

This module can use for converting audio file in original dataset. After you 
get the original audio, you can generate more noise audio if you like. The noise 
audio dataset create way is showed on our website. We provide some exmaple noise 
audio in github. 

################################################################################
# Author: Weikun Han <weikunhan@gmail.com>
# Crate Date: 02/20/2018        
# Update:
# Reference: https://github.com/jhetherly/EnglishSpeechUpsampler
################################################################################
"""

import os
import sox

# Please modify input path  to locate you file
DATASETS_ROOT_DIR = './datasets'
OUTPUT_DIR = os.path.join(DATASETS_ROOT_DIR, 'TEDLIUM_all')
INPUT_DIR = os.path.join(DATASETS_ROOT_DIR, 'TEDLIUM_release2/{}/sph')

# Please modify setting for splice duration
start_time = 30
end_time = -30

# List sub-folder for datasets
input_folder = ['dev', 'test', 'train']

# Check location to save datasets
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)
    
print('Will send .wav audio to {}'.format(OUTPUT_DIR))

# Loop over all files within the TEDLIUM directory first 
for directory in input_folder:
    input_tmp_path = INPUT_DIR.format(directory)
    
    # Loop over all files within the input directory
    for filename in os.listdir(input_tmp_path):
        input_filename = os.path.join(input_tmp_path, filename)

        # Check if path is an existing regular file
        if not os.path.isfile(input_filename):
            continue
        filename_base = os.path.splitext(filename)[0]

        # This is the total audio track duration less the
        # start and end times
        duration = sox.file_info.duration(input_filename) - (start_time -
                                                             end_time)

         # Create final file format
        filename_template = '{}.wav'

        print('On file {}'.format(filename_base))

        # create trasnformer
        splice = sox.Transformer()
        output_filename = filename_template.format(filename_base)
        output_filename = os.path.join(OUTPUT_DIR, output_filename)

        # TODO: splice.trim(start_time, start_time + duration)
        splice.trim(start_time, duration) 
        splice.build(input_filename, output_filename)
# Out:
# Will send .wav audio to ./datasets/TEDLIUM
# On file CraigVenter_2008
# On file BarrySchwartz_2005G
# On file BlaiseAguerayArcas_2007
# On file BrianCox_2009U
# On file DavidMerrill_2009
# On file WadeDavis_2003
# On file ElizabethGilbert_2009
# On file AlGore_2009
# On file TomWujec_2010U
# On file RobertGupta_2010U
# On file GaryFlake_2010
# On file AimeeMullins_2009P
# On file DanBarber_2010
# On file BillGates_2010
# On file JamesCameron_2010
# On file MichaelSpecter_2010
# On file EricMead_2009P
# On file DanielKahneman_2010
# On file JaneMcGonigal_2010
# On file AviRubin_2011X
# On file JanineShepherd_2012X
# On file RobertWright_2006
# On file CorneilleEwango_2007G
# On file SebastianThrun_2011
# On file DavidPizarro_2012X
# On file HaraldHaas_2011G
# On file SethPriebatsch_2010X
# On file EricBerlow_2010G
# On file RachelBotsman_2010X
# On file MariaBezaitis_2013S
# On file BeatriceCoron_2011
# On file EdithWidder_2010Z
# On file SakiMafundikwa_2013
# On file MarcusduSautoy_2009G
# On file ChadeMengTan_2010Z
# On file GeorgeSmoot_2008P
# On file AndrewMcAfee_2013
# On file JulianaRotich_2013G
# On file BenGoldacre_2011G
# On file PamWarhurst_2012S
# On file CharlesLeadbeater_2005G
# On file NathanWolfe_2012U
# On file DebRoy_2011
# On file VanJones_2010X
# On file MartinVilleneuve_2013
# On file JohnUnderkoffler_2010
# On file ElizabethLoftus_2013G
# On file RaghavaKK_2011G
# On file JakeBarton_2013S
# On file StefonHarris_2011S
# On file BreneBrown_2010X
# On file RodneyMullen_2012X
# On file FrederickBalagadde_2010U
# On file StevenJohnson_2010G
# On file JoAnnKucheraMorin_2009
# On file TimBrown_2008P
# On file NicholasNegroponte_2008
# On file SunniBrown_2011
# On file DavidLogan_2009
# On file RichardStJohn_2005
# On file CynthiaSchneider_2009G
# On file BenoitMandelbrot_2010
# On file ChipKidd_2012
# On file LemnSissay_2012X
# On file IvanKrastev_2012G
# On file JodyWilliams_2010W
# On file MarcusByrne_2012X
# On file MargaretHeffernan_2012G
# On file QuyenNguyen_2011P
# On file DorisKearnsGoodwin_2008
# On file ArunachalamMuruganantham_2012S
# On file DeniseHerzing_2013
# On file PhilippeStarck_2007
# On file RobertFull_2002
# On file GeorgeWhitesides_2010
# On file BartKnols_2012X
# On file PaulDebevec_2009X
# On file MarcoTempest_Session7_2011G
# On file CharlesFleischer_2005
# On file JohnWooden_2001
# On file JimToomey_2010Z
# On file FrankWarren_2012
# On file AlexSteffen_2005G
# On file SharmeenObaidChinoy_2010U
# On file KevinBreel_2013X
# On file DannyHillis_1994
# On file LeslieMorganSteiner_2012X
# On file BahiaShehab_2012G
# On file PeterEigen_2009X
# On file DavidBrooks_2011
# On file TheyMightBeGiants_2007
# On file GeoffreyWest_2011G
# On file Rives_Mockingbird_2006
# On file MartinHanczyc_2011S
# On file BrianCox_2008
# On file PatriciaKuhl_2010X
# On file KevinSlavin_2011G
# On file DamonHorowitz_2011
# On file ChrystiaFreeland_2013G
# On file HansRosling_2010S
# On file JanineBenyus_2009G
# On file AntonyGormley_2012G
# On file RonEglash_2007G
# On file JohnSearle_2013
# On file AlexLaskey_2013
# On file AmyWebb_2013S
# On file MarcoTempest_2012
# On file NancyEtcoff_2004
# On file RachelPike_2009G
# On file ShirinNeshat_2010W
# On file GeorgeDyson_2002
# On file OlafurEliasson_2009
# On file CarlSchoonover_2012U
# On file EstherDuflo_2010
# On file Halla_Tomasdottir_2010W
# On file EvanWilliams_2009
# On file LeeSmolin_2003
# On file KakiKing_2008
# On file KevinBales_2010
# On file JohnHockenberry_2012
# On file IanDunbar_2007P
# On file CarneRoss_2009P
# On file ClayShirky_2012S
# On file ChristophAdami_2011X
# On file DaveEggers_2008
# On file JoshuaWalters_2011S
# On file WolfgangKessling_2012S
# On file JohnMcWhorter_2013
# On file TaylorWilson_2012
# On file PaulSereno_2005
# On file NielsDiffrient_2002a
# On file SteveTruglia_2009G
# On file WoodyNorris_2004
# On file DavidPogue_2013U
# On file AmySmith_2006
# On file NiallFerguson_2011G
# On file LorettaNapoleoni_2009G
# On file AndrewMwenda_2007G
# On file SteveRamirez_2013X
# On file StewartBrand_2004
# On file DanDennett_2002
# On file AndrewMcAfee_2012X
# On file KellyMcGonigal_2013G
# On file JamesBGlattfelder_2012X
# On file ElonMusk_2013
# On file GayleLemmon_2011X
# On file LizaDonnelly_2010W
# On file MartinJacques_2010S
# On file NathanMyhrvold_2011U
# On file JamieHeywood_2009P
# On file RoyGould_2008
# On file BillGates_2009
# On file NatashaTsakos_2009
# On file GarrettLisi_2008
# On file AmoryLovins_2012S
# On file MadeleineAlbright_2010W
# On file JosephNye_2010G
# On file RickSmolan_2007P
# On file GoogleScienceFairWinners_2011X
# On file ChrisJordan_2008
# On file MosheSafdie_2002
# On file GeoffreyCanada_2013S
# On file TomThum_2013X
# On file MarcoTempest_2011G
# On file PeterNorvig_2012U
# On file JR_2012
# On file NoahFeldman_2003
# On file AmandaPalmer_2013
# On file HansRosling_2010X
# On file LizDiller_2007P
# On file SkylarTibbits_2011U
# On file DavidGallo_1998
# On file AlastairParvin_2013
# On file TierneyThys_2003
# On file MarkBittman_2007P
# On file FabianHemmert_2009X
# On file Rives_TTYL_2008
# On file CharlesLimb_2010X
# On file ElynSaks_2012G
# On file EvaVertes_2005
# On file RennyGleeson_2012U
# On file MelindaGates_2010X
# On file WadahKhanfar_2011
# On file ReubenMargolin_2012
# On file RickWarren_2006
# On file MaurizioSeracini_2012G
# On file DavidAgus_2009P
# On file MargaretWertheim_2009
# On file NielsDiffrient_2002
# On file DanMeyer_2010X
# On file TomChatfield_2010G
# On file DeanKamen_2002
# On file XDRTB_2008
# On file MarkPagel_2011G
# On file NicholasNegroponte_1984
# On file ManalAlSharif_2013G
# On file DannyHillis_2013
# On file SheilaNirenberg_2011P
# On file PhilHansen_2013
# On file JakobTrollback_2007
# On file EleniGabreMadhin_2007G
# On file SherwinNuland_2001
# On file VikramPatel_2012G
# On file SirenaHuang_2006
# On file JuanEnriquez_2013U
# On file JennaMcCarthy_2011X
# On file DavidAnderson_2013X
# On file EricSanderson_2009G
# On file BillStone_2007
# On file MichaelTilsonThomas_2012
# On file AsherHasan_2009I
# On file FransLanting_2005
# On file RonMcCallum_2013X
# On file RichardSeymour_2011S
# On file StefanSagmeister_2004
# On file EricTopol_2009P
# On file PeterVanManen_2013X
# On file GeertChatrou_2010X
# On file SheilaPatek_2004
# On file StewartBrand_2013
# On file DamianPalin_2012U
# On file JannaLevin_2011
# On file CKWilliams_2001
# On file MikedeGruy_2010Z
# On file MiltonGlaser_1998
# On file GrahamHill_2011U
# On file JohnHodgman_2008
# On file VilayanurRamachandran_2007
# On file ApolloRobbins_2013G
# On file MarcelDicke_2010G
# On file RichardDawkins_2002
# On file IqbalQuadir_2005G
# On file CharityTillemannDick_2010P
# On file BurtRutan_2006
# On file CourtneyMartin_2010W
# On file OliverSacks_2009
# On file PaulMoller_2004
# On file MarcoTempest_2012G
# On file RobinChase_2012G
# On file JohnMaeda_2008P
# On file DeanOrnish_2004
# On file CamilleSeaman_2013
# On file AlanSiegel_2010
# On file HallaTomasdottir_2010W
# On file EdwardBurtynsky_2005
# On file ChristopherMcDougall_2010X
# On file KenKamler_2009P
# On file GordonBrown_2009G
# On file JaneGoodall_2002
# On file TomShannon_2009S
# On file DavidByrne_2010
# On file AngelaPatton_2012X
# On file GeoffMulgan_2011G
# On file ShimonSchocken_2012G
# On file DonaldSadoway_2012
# On file PatriciaRyan_2010X
# On file ElifShafak_2010G
# On file BillJoy_2006
# On file MarkBezos_2011U
# On file RebeccaSaxe_2009G
# On file LaurieSantos_2010G
# On file MartinRees_2005G
# On file KeithBarry_2004
# On file DrewCurtis_2012
# On file MichaelDickinson_2013X
# On file Stew_BlackMenSki_2006
# On file NeilGershenfeld_2006
# On file EliBeer_2013P
# On file BenSaunders_2005
# On file MaryRoach_2009
# On file iOTillettWright_2012X
# On file EliPariser_2011
# On file BobbyGhosh_2012X
# On file JimmyWales_2005G
# On file SimonSinek_2009X
# On file MatthieuRicard_2004
# On file JasonClay_2010G
# On file LesleyHazleton_2010X
# On file EduardoPaes_2012
# On file BjornLomborg_2005
# On file BenKatchor_2002
# On file MikeRowe_2008P
# On file JoshSilver_2009G
# On file JulianTreasure_2011G
# On file BillDavenhall_2009P
# On file PhilPlait_2011X
# On file JohnFrancis_2008
# On file DavidMcCandless_2010G
# On file ClayShirky_2012G
# On file NicMarks_2010G
# On file RichardStJohn_2009U
# On file NateSilver_2009
# On file RyanMerkley_2012G
# On file RobinChase_2007
# On file NicholasChristakis_2010S
# On file BenjaminWallace_2008P
# On file ChristopherDeam_2002
# On file JillSobuleandJuliaSweeneySHOW_2007
# On file EinsteinTheParrot_2006
# On file IvanOransky_2012P
# On file BillyGraham_1998
# On file PatriciaBurchat_2008
# On file JacekUtko_2009
# On file HectorRuiz_2007G
# On file DavidGriffin_2008
# On file EOWilson_2007
# On file DavidKelley_2002
# On file BillClinton_2007
# On file MarcKoska_2009G
# On file ReadMontague_2012G
# On file AmyLockwood_2011G
# On file KarenThompsonWalker_2012G
# On file AdamSadowsky_2010X
# On file JonRonson_2012
# On file AlexisOhanian_2009I
# On file MeganKamerick_2011X
# On file RodneyBrooks_2003
# On file ShimonSchocken_2010X
# On file PeterDonnelly_2005G
# On file TanLe_2010G
# On file BobThurman_2006S
# On file EnricSala_2010Z
# On file MichaelSandel_2010
# On file GolanLevin_2004
# On file EmmaTeeling_2012X
# On file JosetteSheeran_2011G
# On file RogerEbert_2011
# On file JuliaSweeney_2006
# On file CarolineLavelleFARTHERTHANTHESUN_2005
# On file SophalEar_2009U
# On file ChristopherPoole_2010
# On file JacquelineNovogratz_2009U
# On file MajoraCarter_2006
# On file NatalieMacMaster_2003
# On file LizColeman_2009
# On file ThomasSuarez_2011X
# On file MinaBissell_2012G
# On file RachelArmstrong_2009G
# On file MikkoHypponen_2011X
# On file WinghamRowan_2012S
# On file IsabelAllende_2007
# On file DennisvanEngelsdorp_2008P
# On file ErikJohansson_2011S
# On file SylviaEarle_2009
# On file JessicaGreen_2011G
# On file RichardSt.John_2005
# On file MihalyCsikszentmihalyi_2004
# On file MikeMatas_2011
# On file JenniferLin_2004
# On file MajoraCarter_2010X
# On file AdamDavidson_2012S
# On file EdiRama_2012X
# On file EdGavagan_2012P
# On file MikkoHypponen_2011G
# On file RichardDawkins_2005G
# On file AnandAgarawala_2007
# On file CameronHerold_2009X
# On file DavidBlaine_2009P
# On file FeisalAbdulRauf_2009P
# On file BillStrickland_2002
# On file AngelaBelcher_2011X
# On file RussellFoster_2013G
# On file AdamSavage_2008P
# On file SleepyManBanjoBoys_2013
# On file SherwinNuland_2003
# On file ThomasHeatherwick_2011
# On file JanetEchelman_2011
# On file SebastianDeterding_2011X
# On file RamseyMusallam_2013S
# On file AnthonyAtala_2009P
# On file GavinPretorPinney_2013G
# On file LaurenZalaznick_2010W
# On file SvantePaabo_2011G
# On file PhilipZimbardo_2011
# On file HasanElahi_2011G
# On file WillieSmits_2009
# On file KevinKelly_2007P
# On file RobertNeuwirth_2005G
# On file CaryFowler_2009G
# On file HendrikPoinar_2013X
# On file DeeBoersma_2010Z
# On file DorisKimSung_2012X
# On file NicholasNegroponte_2007P
# On file JohnDelaney_2010Z
# On file KaryMullis_2009
# On file RavinAgrawal_2009I
# On file RobertNeuwirth_2005
# On file EveEnsler_2010W
# On file CatherineMohr_2009
# On file PaulMacCready_1998
# On file ClayShirky_2010S
# On file GaryGreenberg_2012X
# On file JanineBenyus_2005
# On file ElliotKrane_2011U
# On file StephenPetranek_2002
# On file CesarKuriyama_2012
# On file Jenny8Lee_2008P
# On file PaulRothemund_2008
# On file BlaiseAguerayArcas_2010
# On file TimBernersLee_2009
# On file JaimeLerner_2007
# On file ChimamandaAdichie_2009G
# On file AmyCuddy_2012G
# On file RennyGleeson_2009
# On file TomWujec_2009GU
# On file NatalieJeremijenko_2009P
# On file FioOmenetto_2011
# On file JamieOliver_2010
# On file BrewsterKahle_2007P
# On file DanGilbert_2005G
# On file JuanEnriquez_2007S
# On file NigelMarsh_2010X
# On file HarshaBhogle_2009I
# On file DavidSRose_2007U
# On file EdwardBurtynsky_2009G
# On file MichaelShermer_2010
# On file ScottMcCloud_2005
# On file MichaelShermer_2006
# On file BryanStevenson_2012
# On file LemonAndersen_2011Y
# On file FrancoSacchi_2007G
# On file SethGodin_2009
# On file AllanJones_2011G
# On file ErikSchlangen_2012X
# On file JohnHunter_2011
# On file BrianSkerry_2010Z
# On file JeremyJackson_2010Z
# On file AmyTan_2008
# On file AlexanderTsiaras_2010P
# On file BenjaminZander_2008
# On file LennartGreen_2005
# On file EleanorLongden_2013
# On file TimBernersLee_2010U
# On file AndrewBird_2010
# On file EricaFrenkel_2011X
# On file DavidDeutsch_2009G
# On file HodLipson_2007
# On file CharlieTodd_2011X
# On file JohnMaeda_2012G
# On file BeebanKidron_2012S
# On file VickiArroyo_2012G
# On file DevduttPattanaik_2009I
# On file DamonHorowitz_2011X
# On file AlanRussell_2006
# On file ChrisBliss_2011X
# On file BillFord_2011
# On file Rives4AM_2007
# On file MichaelGreen_2013
# On file ShaneKoyczan_2013
# On file KateStone_2013
# On file YannArthusBertrand_2009
# On file NateSilver_2009A
# On file TimBrown_2009G
# On file RobReid_2012
# On file SuzanneLee_2011U
# On file MairaKalman_2007
# On file ThomasInsel_2013X
# On file JasonFried_2010X
# On file NeilMacGregor_2011G
# On file ArthurBenjamin_2009
# On file AlGore_2008
# On file CharlesMoore_2009U
# On file TristramStuart_2012S
# On file PeterHirschberg_2007P
# On file HansRosling_2010W
# On file JaneFonda_2011X
# On file YangLan_2011G
# On file ReedKroloff_2003
# On file ZeresenayAlemseged_2007G
# On file StephenColeman_2011X
# On file MassimoBanzi_2012G
# On file BeauLotto_2012G
# On file SheikhaAlMayassa_2010W
# On file DanAriely_2008P
# On file MartinSeligman_2004
# On file JacquelineNovogratz_2010W
# On file JeffSmith_2012S
# On file RogierVanDerHeide_2010X
# On file CandyChang_2012G
# On file RoseGeorge_2013
# On file ThomasDolbyandRachelleGarniezLAVIEENROSE_2004
# On file KirbyFerguson_2012G
# On file JudyJohnston_2013U
# On file PeterTyack_2010Z
# On file RaghavaKK_2012S
# On file LisaMargonelli_2010X
# On file JenniferGranholm_2013
# On file WadeDavis_2012
# On file LudwickMarishane_2012S
# On file FrankGehry_1990
# On file AnthonyAtala_2011
# On file JacquelineNovogratz_2009S
# On file KaryMullis_2002
# On file EmilyPilloton_2010G
# On file DanDennett_2006
# On file PaulRomer_2009G
# On file DonLevy_2012U
# On file DavidChristian_2011
# On file StevenStrogatz_2004R
# On file GregLynn_2005
# On file CharlesLeadbeater_2010S
# On file KristaTippett_2010Z
# On file JohnWalker_2007P
# On file KenJennings_2013X
# On file DavidKeith_2007S
# On file SeanCarroll_2010X
# On file SimonLewis_2010P
# On file SimonBerrow_2010X
# On file SarahKay_2011
# On file TaliSharot_2012
# On file BarrySchwartz_2009
# On file DaphneBavelier_2012X
# On file LeeCronin_2012G
# On file SirKenRobinson_2010
# On file BruceAylward_2011
# On file NickBostrom_2005G
# On file AndreasSchleicher_2012G
# On file DanielWolpert_2011G
# On file SusanLim_2010P
# On file JessicaJackley_2010G
# On file HansRosling_2009S
# On file JulieTaymor_2011
# On file JessaGamble_2010GU
# On file SamMartin_2009G
# On file WilliamMcDonough_2005
# On file DerekSivers_2009I
# On file PameliaKurstin_2002
# On file TomHoney_2005
# On file JillSobuleMANHATTANINJANUARY_2006
# On file FreemanHrabowski_2013
# On file PaulConneally_2011X
# On file RobertoDAngelo_2013G
# On file ErezLiebermanAiden_2011X
# On file Rives_2012S
# On file HadynParry_2012S
# On file LizDiller_2012
# On file DerekSivers_2010U
# On file KeithBellows_2002
# On file IsaacMizrahi_2008
# On file 911Mothers_2010W
# On file CharlesLimb_2011P
# On file StephenHawking_2008
# On file NaliniNadkarni_2009
# On file KathrynSchulz_2011S
# On file MattKillingsworth_2011X
# On file FrancisCollins_2012P
# On file CarlSafina_2010X
# On file MikeBiddle_2011G
# On file PaddyAshdown_2011X
# On file ThandieNewton_2011G
# On file KelliSwazey_2013P
# On file PhilippePetit_2012
# On file NickSears_2007
# On file AndersYnnerman_2010X
# On file KevinSurace_2009
# On file MorganSpurlock_2011
# On file CherylHayashi_2010
# On file ClayShirky_2005G
# On file CarolynPorco_2007
# On file NoreenaHertz_2010S
# On file AlSeckel_2004
# On file CornielleEwango_2007G
# On file TomWujec_2009G
# On file WadeDavis_2008
# On file NgoziOkonjoIweala_2007G
# On file Jennifer8Lee_2008P
# On file RobertBallard_2008
# On file BruceBuenodeMesquita_2009
# On file KevinKelly_2005
# On file AfraRaymond_2012X
# On file StevenPinker_2005G
# On file EWidder_2010Z
# On file MunirVirani_2012S
# On file ThomasThwaites_2010S
# On file MattRidley_2010G
# On file JonathanHaidt_2012S
# On file ChristienMeindertsma_2010G
# On file PaolaAntonelli_2013S
# On file TarynSimon_2011S
# On file JasonMcCue_2012G
# On file TheLXD_2010
# On file JuanEnriquez_2003
# On file MichaelPawlyn_2010S
# On file BruceFeiler_2013S
# On file EricDishman_2009P
# On file DavidGallo_2007
# On file RobHopkins_2009G
# On file KristenAshburn_2003
# On file BirkeBaehr_2010X
# On file MichaelArcher_2013X
# On file AndyPuddicombe_2012S
# On file CliffordStoll_2006
# On file LisaGansky_2011S
# On file NathanielKahn_2002
# On file PawanSinha_2009I
# On file SeyiOyesola_2007G
# On file TomWujec_2009U
# On file JohnBohannon_2011X
# On file SamHarris_2010
# On file GeorgeMonbiot_2013G
# On file KellerRinaudo_2013
# On file AlaindeBotton_2011G
# On file MarkRoth_2010
# On file HeribertWatzke_2010G
# On file LewisPugh_2010G
# On file RomulusWhitaker_2009I
# On file DavidHoffman_2008
# On file BruceSchneier_2010X
# On file RonnyEdry_2012X
# On file TarynSimon_2009G
# On file HelenFisher_2008
# On file MishaGlenny_2009G
# On file JamesHowardKunstler_2004
# On file RobertGupta_2012P
# On file JanChipchase_2007
# On file NinaJablonski_2009
# On file DonTapscott_2012G
# On file BernieKrause_2013G
# On file JohnMaeda_2007
# On file BenGoldacre_2012P
# On file DanPhillips_2010X
# On file HansRosling_2009
# On file JamaisCascio_2006
# On file PaolaAntonelli_2007P
# On file AdoraSvitak_2010
# On file KarenArmstrong_2009G
# On file YochaiBenkler_2005G
# On file ChrisAnderson_2004
# On file JuliaSweeney_2010
# On file BarbaraBlock_2010Z
# On file EllenGustafson_2010X
# On file KimGorgens_2010X
# On file DavidPogue_2008P
# On file CarmenAgraDeedy_2005
# On file BeckyBlanton_2009G
# On file LarryBurns_2005
# On file TeresaCarrenoOrchestra_2009
# On file SheenaIyengar_2011S
# On file DeborahGordon_2003
# On file EmmanuelJal_2009G
# On file EricDishman_2013S
# On file MarcPachter_2008P
# On file ShaffiMather_2009I
# On file EricWhitacre_2011
# On file YvesBehar_2008
# On file DanielPink_2009G
# On file MarkhamNolan_2012S
# On file DanAriely_2012X
# On file EuvinNaidoo_2007G
# On file JulianTreasure_2010G
# On file JamesForbes_2009P
# On file HelenFisher_2006
# On file SirKenRobinson_2013S
# On file JosephPine_2004
# On file CameronSinclair_2006
# On file SrdjaPopovic_2011X
# On file YvesRossy_2011G
# On file PeterReinhart_2008P
# On file PenelopeBoston_2006
# On file RichardPreston_2008
# On file VusiMahlasela_SongofMama_2007G
# On file CamilleSeaman_2011U
# On file JDSchramm_2011A
# On file SamRichards_2010X
# On file DanielTammet_2011
# On file AshrafGhani_2005G
# On file UeliGegenschatz_2009
# On file JoshuaPrinceRamus_2009X
# On file JakeWood_2011X
# On file JeffHan_2006
# On file JulieBurstein_2012
# On file MichaelAnti_2012G
# On file SirKenRobinson_2006
# On file TorstenReil_2003
# On file DavidBolinsky_2007
# On file JeremyGilley_2011G
# On file PaulEwald_2007
# On file BecciManson_2012G
# On file LauraCarstensen_2011X
# On file DianeBenscoter_2009U
# On file JamesNachtwey_2007
# On file BreneBrown_2012
# On file JinsopLee_2013
# On file JeffBezos_2003
# On file RichardResnick_2011X
# On file JamesBalog_2009G
# On file DavidPogue_2006
# On file DanielKraft_2011X
# On file ShaiAgassi_2009
# On file PankajGhemawat_2012G
# On file PeterAttia_2013P
# On file KarenArmstrong_2008
# On file PhilZimbardo_2008
# On file NadiaAlSakkaf_2011G
# On file ChipConley_2010
# On file Beardyman_2013
# On file AmosWinter_2012X
# On file TimHarford_2011G
# On file RorySutherland_2011X
# On file MichaelMcDaniel_2012X
# On file AmberCase_2010W
# On file StewartBrand_2009S
# On file GarthLenz_2011X
# On file JohnWilbanks_2012G
# On file SebastiaoSalgado_2013
# On file IanGoldin_2009G
# On file IsabelBehnckeIzquierdo_2011U
# On file JustinHallTipping_2011G
# On file JoelLevine_2009X
# On file MatthewChilds_2009U
# On file StewartBrand_2006
# On file JulianTreasure_2010GU
# On file GeverTulley_2007U
# On file PaulMacCready_2003
# On file MustafaAkyol_2011X
# On file Naturally7FLYBABY_2009
# On file RoryBremner_2009G
# On file DavidMacaulay_2002
# On file SebastianWernicke_2011X
# On file BastianSchaefer_2013G
# On file LouieSchwartzberg_2011U
# On file BartonSeaver_2010Z
# On file MitchResnick_2012X
# On file BarrySchwartz_2010S
# On file SarahJayneBlakemore_2012G
# On file RAMashelkar_2009I
# On file RobertGordon_2013
# On file JohnnyLee_2008
# On file SherylSandberg_2010W
# On file WilliamKamkwamba_2007G
# On file WillWright_2007
# On file StefanSagmeister_2010S
# On file RorySutherland_2009G
# On file JacquelineNovogratz_2007G
# On file MichaelMerzenich_2004
# On file EOWilson_2012P
# On file NathanWolfe_2009
# On file BunkerRoy_2011G
# On file PaulaScher_2008P
# On file ZachKaplan_2005
# On file ThomasBarnett_2005
# On file AllanSavory_2013
# On file JohnGerzema_2009X
# On file WaelGhonim_2011X
# On file SarahJones_2009
# On file ElizabethLindsey_2010W
# On file JulianaMachadoFerreira_2010U
# On file ShereenElFeki_2012S
# On file RobertFull_2005
# On file LuisVonAhn_2011X
# On file DanielLibeskind_2009
# On file FreemanDyson_2003
# On file RobForbes_2006
# On file SugataMitra_2013
# On file ScillaElworthy_2012X
# On file DavidCameron_2010
# On file TimFerriss_2008P
# On file JamilAbuWardeh_2010G
# On file JillBolteTaylor_2008
# On file JonathanHaidt_2012
# On file RaffaelloDAndrea_2013G
# On file JamesRandi_2007
# On file DanielSuarez_2013G
# On file AnnaMracekDietrich_2011G
# On file AlisaMiller_2008
# On file JeffreySkoll_2007
# On file JessaGamble_2010G
# On file StevenPinker_2003
# On file GordonBrown_QA_2009G
# On file ThomMayne_2005
# On file TylerDeWitt_2012X
# On file SaulGriffith_2006
# On file PeterSinger_2013
# On file StevenPetranek_2002
# On file RivesINTERNET_2006S
# On file CarolynSteel_2009G
# On file CraigVenter_2010P
# On file SunithaKrishnan_2009I
# On file DannyHillis_2010P
# On file SebastianSeung_2010G
# On file PaulCollier_2009S
# On file KirkCitron_2010
# On file JohannaBlakley_2010X
# On file DavidCarson_2003
# On file RobHarmon_2010X
# On file KatherineFulton_2007
# On file AubreydeGrey_2005G
# On file AlexaMeade_2013G
# On file ScottFraser_2012X
# On file CalebChung_2007P
# On file PaulPholeros_2013X
# On file MitchellBesser_2010G
# On file JPRangaswami_2012S
# On file StevenLevitt_2004
# On file CarloRatti_2011
# On file BrittaRiley_2011X
# On file ChrisBangle_2002
# On file GaryWolf_2010S
# On file EllenDunhamJones_2010X
# On file JamieDrummond_2012G
# On file MarisaFickJordan_2007G2
# On file MirandaWang_2013
# On file DanAriely_2009
# On file PranavMistry_2009I
# On file HeatherKnight_2010W
# On file RoryStewart_2012X
# On file RobertLang_2008
# On file GeoffMulgan_2009G
# On file PaulStamets_2008
# On file JohnHardy_2010G
# On file StephenPalumbi_2010Z
# On file JaredFicklin_2012
# On file MitchellJoachim_2010
# On file LucienEngelen_2011X
# On file BruceFeiler_2010P
# On file RossLovegrove_2005
# On file DeanKamen_2009P
# On file BandiMbubi_2012X
# On file MickEbeling_2011A
# On file ItayTalgam_2009G
# On file JuanEnriquez_2012S
# On file GrahamHawkes_2005
# On file JackHorner_2011
# On file JackHorner_2010X
# On file LaliteshKattragadda_2009I
# On file ThulasirajRavilla_2009I
# On file KartickSatyanarayan_2009I
# On file HansRosling_2007
# On file FrankGehry_2002
# On file BenKacyra_2011G
# On file TheAhnTrio_2010W
# On file ArisVenetikidis_2012X
# On file JaredDiamond_2003
# On file ErikBrynjolfsson_2013
# On file DeborahRhodes_2010W
# On file JuanEnriquez_2009
# On file RichardWilkinson_2011G
# On file MazJobrani_2012S
# On file CarolineCasey_2010W
# On file MechaiViravaidya_2010X
# On file LucaTurin_2005
# On file JiHaePark_2013
# On file JohnDoerr_2007
# On file ShigeruBan_2013X
# On file JamesStavridis_2012G
# On file JanePoynter_2009X
# On file ChrisAnderson_2010G
# On file HillelCooperman_2010U
# On file AlVernacchio_2012
# On file GarikIsraelian_2009G
# On file SuheirHammad_2010W
# On file JeffHawkins_2003
# On file JohanRockstrom_2010G
# On file LisaHarouni_2011S
# On file NellieMcKayCLONIE_2008
# On file JonathanTrent_2012G
# On file DiannaCohen_2010Z
# On file AnasAremeyawAnas_2013
# On file SriSwamiDayanandaSaraswati_2009P
# On file FransDeWaal_2011X
# On file BenSaunders_2012S
# On file KevinAllocca_2011Y
# On file BLACK_2013
# On file MichaelMilken_2001
# On file TyroneHayes_2010W
# On file AndrewBlum_2012G
# On file RivesTTYL_2008
# On file WilliamKamkwamba_2009G
# On file JohannaBlakley_2010W
# On file TerryMoore_2012
# On file JaneChen_2009I
# On file AnnieLennox_2010G
# On file CharlesElachi_2008P
# On file TheoJansen_2007
# On file LiuBolin_2013
# On file TimJackson_2010G
# On file ZeFrank_2010G
# On file RobertFischell_2005
# On file ThomasGoetz_2010P
# On file JohnGrahamCumming_2012X
# On file LisaKristine_2012X
# On file DanCobley_2010G
# On file AdamOstrow_2011G
# On file NormanFoster_2007P
# On file TimothyPrestero_2012X
# On file EythorBender_2011
# On file JonathanDrori_2009U
# On file DidierSornette_2013G
# On file JoshuaFoer_2012
# On file AyahBdeir_2012U
# On file DonNorman_2003
# On file JillTarter_2009
# On file CarlHonore_2005G
# On file KentLarson_2012X
# On file JonasEliasson_2012X
# On file KarenTse_2011G
# On file ReginaDugan_2012
# On file DenisDutton_2010
# On file StaceyKramer_2010
# On file KakenyaNtaiya_2012X
# On file MagnusLarsson_2009G
# On file StephenLawler_2007
# On file DanBarber_2008P
# On file NatalieMerchant_2010
# On file EdUlbrich_2009
# On file StevenJohnson_2003
# On file SueAustin_2012X
# On file LawrenceLessig_2010X
# On file EdwardTenner_2011
# On file SheenaIyengar_2010G
# On file AaronOConnell_2011
# On file MarvinMinsky_2003
# On file AmiKlin_2011X
# On file NandanNilekani_2009
# On file NiloferMerchant_2013
# On file AnilAnanthaswamy_2010P
# On file ChrisGerdes_2012X
# On file DanielKraft_2009
# On file UrsusWehrli_2006
# On file RayKurzweil_2005
# On file BenDunlap_2007
# On file StevenPinker_2007
# On file ChrisAbani_2007G
# On file EricXLi_2013G
# On file AaronKoblin_2011
# On file SethShostak_2012X
# On file JayWalker_2009
# On file ShimonSteinberg_2010X
# On file AmoryLovins_2005
# On file RonGutman_2011U
# On file JonathanFoley_2010X
# On file StefanSagmeister_2009G
# On file PeterGabriel_2006
# On file EstherPerel_2013S
# On file KenGoldberg_2012X
# On file KevinStone_2010U
# On file ToddHumphreys_2012X
# On file MyshkinIngawale_2012U
# On file NaomiKlein_2010W
# On file EddiReaderWHATYOUDO_2004
# On file ChrisAnderson_2002
# On file JaySilver_2013S
# On file DennisHong_2009X
# On file HansRosling_2012S
# On file ClayShirky_2009S
# On file RobertHammond_2011U
# On file MargaretStewart_2010U
# On file MayaBeiser_2011
# On file LucyMcRae_2012
# On file DavidMackay_2012X
# On file EllenTHoen_2012X
# On file KateHartman_2011
# On file PaulZak_2011G
# On file BarrySchuler_2008P
# On file DavidDeutsch_2005G
# On file SethGodin_2003
# On file StewBLACKMENSKI_2006
# On file ZainabSalbi_2010G
# On file PeterWard_2008
# On file StephenWolfram_2010
# On file ThelmaGolden_2009
# On file MaeJemison_2002
# On file CarolinePhillips_2010G
# On file MichaelHansmeyer_2012G
# On file DanCohen_2013X
# On file AngelaDuckworth_2013S
# On file MichaelMoschen_2002
# On file JoseAntonioAbreu_2009
# On file TempleGrandin_2010
# On file BartWeetjens_2010X
# On file StevenSchwaitzberg_2012X
# On file RamonaPierson_2011X
# On file RichardWeller_2012X
# On file AlanKay_2007
# On file AtulGawande_2012
# On file RaulMidonANSWERS_2007
# On file BeverlyJoubertandDereckJoubert_2010W
# On file EvelynGlennie_2003
# On file StevenCowley_2009G
# On file JessicaGreen_2013U
# On file JoeSmith_2012X
# On file ErnestoSirolli_2012X
# On file AnandaShankar_2009I
# On file IngeMissmahl_2010G
# On file YvesBehar_2009
# On file CharlesHazlewood_2011G
# On file PaoloCardini_2012G
# On file LarryLessig_2007
# On file AdamSpencer_2013
# On file KeithChen_2012G
# On file JohnKasaona_2010
# On file SherylWuDunn_2010G
# On file RaghavaKK_2010
# On file NeilHarbisson_2012G
# On file PaulSnelgrove_2011G
# On file ShyamSankar_2012G
# On file RufusGriscomandAlisaVolkman_2010W
# On file PaolaAntonelli_2007
# On file JosephKim_2013G
# On file StefanWolff_2010G
# On file HeatherBrooke_2012G
# On file TonyPorter_2010W
# On file MalteSpitz_2012G
# On file JackAndraka_2013
# On file MazJobrani_2010G
# On file ShereenElFeki_2009G
# On file JohannaBlakley_2009X
# On file JenniferHealey_2013X
# On file SkylarTibbits_2013U
# On file PaulGilding_2012
# On file MurrayGellMann_2007
# On file SteveKeil_2011X
# On file DavidKelley_2012
# On file MiruKim_2008P
# On file TomShannon_2003
# On file RameshRaskar_2012G
# On file KevinKelly_2009X
# On file DanPallotta_2013
# On file LouieSchwartzberg_2011X
# On file LauraSnyder_2012G
# On file GeverTulley_2009
# On file RayZahab_2009
# On file BoazAlmog_2012G
# On file JonathanDrori_2010U
# On file PhilipHoward_2010
# On file JayBradner_2011X
# On file MichaelPollan_2007
# On file GregoryStock_2003
# On file StuartBrown_2008P
# On file JonathanHarris_2007
# On file RubyWax_2012G
# On file OryOkolloh_2007G
# On file RobertNeuwirth_2012G
# On file LarryBrilliant_2007P
# On file BethNoveck_2012G
# On file MollyCrockett_2012S
# On file GabrielBarciaColombo_2012
# On file JasonPontin_2013U
# On file SusanCain_2012
# On file HomaroCantu_2011
# On file MalcolmGladwell_2004
# On file AJJacobs_2011P
# On file EvgenyMorozov_2009G
# On file StuartFirestein_2013
# On file DrHawaAbdiandDrDeqoMohamed_2010W
# On file MattMills_2012G
# On file MishaGlenny_2011G
# On file PeterDiamandis_2012
# On file LisaBu_2013
# On file JillSobuleandJuliaSweeney_TheJillandJuliaShow_2007
# On file MallikaSarabhai_2009I
# On file GaryLauder_2010
# On file BenCameron_2010X
# On file JonathanEisen_2012P
# On file OnoraONeill_2013X
# On file JohnLaGrou_2009
# On file StefanSagmeister_2008
# On file BillGates_2013S
# On file KateOrff_2010W
# On file JohnHodgman_2012
# On file ErnestMadu_2007G
# On file HannahBrencher_2012S
# On file HisHolinessTheKarmapa_2009I
# On file FabianOefner_2013G
# On file PaulBloom_2011G
# On file JoshuaKlein_2008
# On file PeteAlcorn_2009
# On file BrianGreene_2012
# On file RobertWright_2009P
# On file GeorgeDyson_2003
# On file NoahWilsonRich_2012X
# On file MegJay_2013
# On file KwabenaBoahen_2007G
# On file PattieMaes_2009
# On file ElaineMorgan_2009G
# On file NgoziOkonjoIweala_2007
# On file StefanaBroadbent_2009G
# On file PeterDiamandis_2005G
# On file BrianGoldman_2011X
# On file PeterGabriel_Panel_2013
# On file BrianCox_2010S
# On file AlexTabarrok_2009
# On file VinayVenkatraman_2012S
# On file SethBerkley_2010
# On file HandspringPuppetCompany_2011
# On file PhilipRosedale_2008P
# On file FelixDennis_2004
# On file MalcolmGladwell_2013S
# On file PaulRothemund_2007
# On file AnnieMurphyPaul_2011G
# On file LakshmiPratury_2007
# On file PhilZimbardo_2009U
# On file JaninediGiovanni_2012X
# On file TerryMoore_2005
# On file LucianneWalkowicz_2011G
# On file JanePoynter_2009
# On file ThomasCampbell_2012
# On file GolanLevin_2009
# On file JR_2011
# On file MarisaFickJordan_2007G
# On file StevenJohnson_2006S
# On file LewisPugh_2009G
# On file JohanRockstroem_2010G
# On file TaniaLuna_2012S
# On file PamelaMeyer_2011G
# On file BrendaLaurel_1998
# On file TheRaspyniBrothers_2002
# On file HowardRheingold_2005
# On file VikMuniz_2003
# On file MarcGoodman_2012G
# On file PWSinger_2009
# On file AbigailWashburn_2012U
# On file AuretvanHeerden_2010G
# On file MathieuLehanneur_2009G
# On file DavedeBronkart_2010X
# On file JarrettJKrosoczka_2012X
# On file KamalMeattle_2009U
# On file StephenRitz_2012X
# On file JakeShimabukuro_2010
# On file LarrySmith_2011X
# On file AndresLozano_2013X
# On file TimothyBartik_2012X
# On file AriannaHuffington_2010W
# On file AnupamMishra_2009I
# On file VirginiaPostrel_2004
# On file SanjayPradhan_2012G
# On file NellieMcKayFEMINISTSIF_2008
# On file BabaShiv_2012X
# On file BillGates_2011U
# On file KiranBirSethi_2009I
# On file ArthurBenjamin_2005
# On file AndrasForgacs_2013G
# On file JinhaLee_2013
# On file PatrickChappatte_2010G
# On file LeymahGbowee_2012
# On file RodneyBrooks_2013
# On file DanielPauly_2010Z
# On file RivesMOCKINGBIRD_2006
# On file AlwarBalasubramaniam_2009I
# On file MalcolmLondon_2013S
# On file DavidBismark_2010G
# On file SoniaShah_2013G
# On file SonaarLuthra_2011G
# On file RichardSears_2010U
# On file RicElias_2011U
# On file JonathanHaidt_2008
# On file RayKurzweil_2009U
# On file MelissaMarshall_2012G
# On file RonFinley_2013
# On file AliceDreger_2011X
# On file PeterHaas_2010G
# On file ArthurPottsDawson_2010G
# On file JamesSurowiecki_2005
# On file GaryKovacs_2012U
# On file HenryMarkram_2009G
# On file LauraTrice_2008
# On file DianaNyad_2011P
# On file NirmalyaKumar_2012X
# On file DanAriely_2011U
# On file MargaretHeffernan_2013X
# On file SiegfriedWoldhek_2008
# On file JulianTreasure_2009G
# On file DanielGoldstein_2011S
# On file MalcolmGladwell_2011G
# On file RorySutherland_2010S
# On file EdithWidder_2011
# On file KeithSchachtandZachKaplan_2005
# On file TanLe_2011X
# On file BrendaBrathwaite_2011X
# On file EmilyLevine_2002
# On file NeilBurgess_2011S
# On file JoshuaPrinceRamus_2006
# On file MiguelNicolelis_2012P
# On file LarryBrilliant_2006
# On file LaurieGarrett_2007U
# On file BobMankoff_2013S
# On file SasaVucinic_2005G
# On file NuclearDebate_2010
# On file AdamGarone_2011X
# On file PaulNicklen_2011
# On file JamesGeary_2009G
# On file StevenLevitt_2005G
# On file LeonardSusskind_2011X
# On file RoryStewart_2011G
# On file RobDunbar_2010Z
# On file AdamOckelford_2013X
# On file SaulGriffith_2009
# On file ArvindGupta_2010P
# On file BenjaminBarber_2013G
# On file WillardWigan_2009G
# On file NathanMyhrvold_2010
# On file PavanSukhdev_2011G
# On file SanjayDastoor_2013
# On file AlisonJackson_2005G
# On file SalmanKhan_2011
# On file MattCutts_2011U
# On file GeroMiesenboeck_2010G
# On file ShlomoBenartzi_2011S
# On file JokChurch_2007
# On file JonathanDrori_2011S
# On file ConradWolfram_2010G
# On file BjarkeIngels_2009G
# On file SusanShaw_2010X
# On file EdithWidder_2013
# On file WayneMcGregor_2012G
# On file RalphLangner_2011
# On file FahadAlAttiya_2012S
# On file LeeCronin_2011G
# On file ClaronMcFadden_2010X
# On file DimitarSasselov_2010G
# On file RajeshRao_2011
# On file AimeeMullins_1998
# On file DavidHoffman_2007
# On file TalGolesworthy_2011X
# On file ZahraLanghi_2012X
# On file TracyChevalier_2012S
# On file IrwinRedlener_2008
# On file JamesFlynn_2013
# On file PeterSaul_2011X
# On file JacksonKatz_2012X
# On file BrunoBowden_2008
# On file MayElKhalil_2013G
# On file SeanGourley_2009U
# On file YoavMedan_2011P
# On file RaulMidonEVERYBODY_2007
# On file LeslieChang_2012G
# On file NellieMcKayTHEDOGSONG_2008
# On file DanGilbert_2004
# On file PatrickAwuah_2007G
# On file ShaoLanHsueh_2013
# On file ShashiTharoor_2009I
# On file KathrynSchulz_2011
# On file NoelMerz_2011X
# On file JonathanHarris_2007P
# On file AlexSteffen_2011G
# On file TonyRobbins_2006
# On file LZGranderson_2012X
# On file AaronHuey_2010X
# On file CynthiaBreazeal_2010W
# On file JosephLekuton_2007G
# On file JamesLyne_2013
# On file Rives_IfIControlledtheInternet_2006S
# On file NinaTandon_2012G
# On file DanDennett_2009U
# On file EveEnsler_2005G
# On file RobertThurman_2009P
# On file SergeyBrin_2004
# On file HonorHarger_2011S
# On file BillGross_2003
# On file JoeSabia_2011S
# On file EamesDemetrios_2007
# On file MarkusFischer_2011G
# On file JaneGoodall_2007G
# On file PhilipeStarck_2007
# On file DerekSivers_2010G
# On file LesleyHazleton_2013G
# On file JessiArrington_2011A
# On file RozSavage_2010Z
# On file HansRosling_2006
# On file AlaindeBotton_2009G
# On file AditiShankardass_2009I
# On file FieldsWickerMiurin_2009S
# On file EveEnsler_2004
# On file DavidDow_2012X
# On file ElizabethLesser_2010W
# On file ZeFrank_2004
# On file WilliamUry_2010X
# On file BrianGreene_2005
# On file AbrahamVerghese_2011G
# On file NickVeasey_2009G
# On file PicoIyer_2013G
# On file PaulWolpe_2010X
# On file MarcoTempest_Session4_2012
# On file JonathanKlein_2010U
# On file SergeyBrin_2013
# On file AlisonGopnik_2011G
# On file EricWhitacre_2013
# On file JimFallon_2009
# On file DyandeNapoli_2011X
# On file KavitaRamdas_2009I
# On file AnnCooper_2007P
# On file ReggieWatts_2012
# On file JonasGahrStore_2011X
# On file RichardTurere_2013
# On file EmilyOster_2007
# On file PaulCollier_2008
# On file MarianBantjes_2010
# On file ChristopherdeCharms_2008
# On file GregStone_2010Z
# On file RitaPierson_2013S
# On file RachelBotsman_2012G
# On file SteveJurvetson_2007
# On file KiranBedi_2010W
# On file PaulKempRobertson_2013G
# On file NewtonAduaka_2007G
# On file JarrethMerz_2011G
# On file PhilBorges_2006
# On file CesarHarada_2012S
# On file WilliamNoel_2012S
# On file RonEglash_2007G2
# On file AllisonHunt_2007
# On file DanBuettner_2009X
# On file CarterEmmart_2010
# On file RichardBranson_2007
# On file HannaRosin_2010W
# On file DrewDudley_2011X
# On file CarolynPorco_2009U
# On file Saraswati_2009P
# On file PeterMolyneux_2010G
# On file AndrewSolomon_2013P
# On file SherryTurkle_2012
# On file MurrayGellMannLANGUAGE_2007
# On file ParagKhanna_2009G
# On file YossiVardi_2007
# On file LeahBuechley_2011Y
# On file DianaLaufenberg_2010X
# On file NathanMyhrvold_2007
# On file JeffHancock_2012X
# On file ColinPowell_2012X
# On file GeorgePapandreou_2013G
# On file JenniferPahlka_2012
# On file JoshuaPrager_2013
# On file ShuklaBose_2009I
# On file MurrayGellMann_Language_2007
# On file VilayanurRamachandran_2009I
# On file AlbertoCairo_2011X
# On file AimeeMullins_2009U
# On file AntonioDamasio_2011
# On file MarkForsyth_2012X
# On file JuliaBacha_2011G
# On file DavidPogue_2007
# On file DaleDougherty_2011S
# On file JoachimdePosada_2009U
# On file DeanKamen_2007
# On file ThomasDolby_2010
# On file ShawnAchor_2011X
# On file SpencerWells_2007G
# On file RobinInce_2011G
# On file OmarAhmad_2010U
# On file TomRielly_2006
# On file ArielGarten_2011X
# On file TBoonePickens_2012
# On file DeborahScranton_2007
# On file MenaTrott_2006
# On file MichelleObama_2009P
# On file MaxLittle_2012G
# On file EvanGrant_2009G
# On file MichaelPritchard_2009G
# On file JonathanDrori_2007U
# On file NaifAlMutawa_2010G
# On file HansRosling_2009I
# On file CharlesAnderson_2009I
# On file NicholasChristakis_2010
# On file PeterHirshberg_2007P
# On file EveEnsler_2009I
# On file HarveyFineberg_2011
# On file DennisHong_2011
# On file ColinRobertson_2012
# On file BruceMcCall_2008P
# On file JoelSelanikio_2013X
# On file TaviGevinson_2012X
# On file EbenBayer_2010G
# On file KarenBass_2012
# On file AnnaDeavereSmith_2005
# On file MichaelNorton_2011X
# On file RyanLobo_2009I
# On file PeterFankhauser_2011G
# On file DavidRockwell_2002
# On file MarcinJakubowski_2011U
# On file JamesWatson_2005
# On file AnilGupta_2009I
# On file SamanthaPower_2008
# On file ElizabethPisani_2010
# On file IainHutchison_2010G
# On file KRamdas_2009I
# On file PeterDiamandis_2008
# On file JJAbrams_2007
# On file GrahamHill_2010
# On file JaneMcGonigal_2012G
# On file FaithJegede_2012S
# On file BertrandPiccard_2009G
# On file RachelSussman_2010G
# On file AlGore_2006
# On file RayAnderson_2009
# On file EddieObeng_2012G
# On file NoraYorkWHATIWANT_2006S
# On file NicholasNegroponte_2006
# On file SheaHembrey_2011
# On file RebeccaOnie_2012P
# On file DavidHanson_2009
# On file StevenAddis_2012
# On file DaphneKoller_2012G
# On file CatherineMohr_2010U
# On file YashengHuang_2011G
# On file MonikaBulaj_2011G
# On file JonathanZittrain_2009G
# On file DaliaMogahed_2012S
# On file CatarinaMota_2012G
# On file AnnMarieThomas_2011
# On file JackieTabick_2009P
# On file ColinStokes_2012X
# On file TodMachover_2008
# On file DrewBerry_2011X
# On file SebastianWernicke_2010A
# On file ErinMcKean_2007
# On file LarryLessig_2013
# On file BeauLotto_2009G
# On file BillDoyle_2011P
# On file NathalieMiebach_2011G
# On file ChrisAbani_2008
# On file StevenStrogatz_2004
# On file RobLegato_2012G
# On file JacquelineNovogratz_2005G
# On file JoanHalifax_2010W
# On file WilliamLi_2010
# On file LaliteshKatragadda_2009I
# On file EricGiler_2009G
# On file EvaZeisel_2001
# On file BoghumaKabisenTitanji_2012X
# On file BillyCollins_2012
# On file CharmianGooch_2013G
# On file EthanZuckerman_2010G
# On file KeesMoeliker_2013
# On file TimLeberecht_2012G
# On file CynthiaKenyon_2011G
# On file JaeRhimLee_2011G
# On file RebeccaMacKinnon_2011G
# On file CraigVenter_2005G
# On file Bono_2005
# On file LouiseLeakey_2008
# On file JehaneNoujaim_2006
# On file JayWalker_2008
# On file JonNguyen_2011X
# On file HyeonseoLee_2013
# On file GeorgetteMulheir_2012S
# On file AparnaRao_2011G
# On file DianeKelly_2012P
# On file NeilTurok_2008
# On file KristinaGjerde_2010Z
# On file EllenJorgensen_2012G
# On file MarkApplebaum_2012X
# On file CameronRussell_2012X
# On file DavidPerry_2006
# On file AdamGrosser_2007
# On file GregoryPetsko_2008
# On file BonnieBassler_2009
# On file JeanBaptisteMichel_2012
# On file EdBoyden_2011
# On file Bono_2013
# On file JulianAssange_2010G
# On file StefanoMancuso_2010G
# On file LeeHotz_2010G
# On file SusanBlackmore_2008
# On file DavidBinder_2012G
# On file AmitSood_2011
# On file SusanSavageRumbaugh_2004
# On file ShekharKapur_2009I
# On file RichardPyle_2004
# On file SendhilMullainathan_2009I
# On file SugataMitra_2007P
# On file ScottKim_2008P
# On file VijayKumar_2012
# On file JackChoi_2012
# On file ElizabethMurchison_2011G
# On file GeorgeAyittey_2007G
# On file AlannaShaikh_2012G
# On file DanielGoleman_2007
# On file EricBerlow_2013U
# On file NancyLublin_2012U
# On file PetervanUhm_2011X
# On file GeorgeWhitesides_2009X
# On file ImamFeisalAbdulRauf_2009P
# On file ChristinaWarinner_2012U
# On file JulianTreasure_2012G
# On file LouiseFresco_2009
# On file DeanOrnish_2008
# On file SusanSolomon_2012G
# On file CameronSinclair_2009G
# On file RobertFull_2009
# On file PaulBennett_2005G
# On file AliCarrChellman_2010X
# On file MarlaSpivak_2013G
# On file MaajidNawaz_2011G
# On file ToddKuiken_2011G
# On file DeanOrnish_2006
# On file NinaTandon_2011U
# On file ArthurGanson_2004
# On file ErikHersman_2009U
# On file JamesHansen_2012
# On file SarahParcak_2012U
# On file RichardBaraniuk_2006
# On file CaitriaONeill_2012X
# On file ShiloSuleman_2011P
# On file DavidHolt_2004
# On file RaulMidon_Tembererana_2007
# On file JoeDeRisi_2006
# On file DanDennett_2003
# On file StanleyMcChrystal_2011
# On file ColinCamerer_2013X
# On file NaliniNadkarni_2010U
# On file Rives_4AM_2007
# On file TaylorWilson_2013
# On file SugataMitra_2010G
# On file DaveMeslin_2010X
# On file VusiMahlaselaSONGOFMAMA_2007G
# On file AndreaGhez_2009G
# On file PearlArredondo_2013S
# On file PaulRomer_2011U
# On file JohnLloyd_2009G
# On file MarkShaw_2013
# On file AJJacobs_2007P
# On file NeilPasricha_2010X
# On file IanRitchie_2011G
# On file ShabanaBasijRasikh_2012X
