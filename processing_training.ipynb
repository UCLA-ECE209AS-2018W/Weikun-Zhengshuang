# %%
# %matplotlib inline

# %% [markdown]
# # The script to train the deep neural networks

# %% [markdown]
# This module can use for processing training. You need modify the number of epochs you want, the size of batch, the initial learning rate, the devay factor for changing learning rate, and number of epochs to decay learning rate. And you can modify output directory you want and input directory you have.

# %%
# -*- coding: utf-8 -*-
""" The script to train the deep neural networks

This module can use for processing training. You need modify the number of 
epochs you want, the size of batch, the initial learning rate, the devay factor 
for changing learning rate, and number of epochs to decay learning rate. And you 
can modify output directory you want and input directory you have.

################################################################################
# Author: Weikun Han <weikunhan@gmail.com>
# Crate Date: 03/10/2018        
# Update:
# Reference: https://github.com/jhetherly/EnglishSpeechUpsampler
################################################################################
"""

import numpy as np
import os
import librosa
import tensorflow as tf
from converter_generator import bitrates_and_waveforms
from converter_generator import get_original_noise_pairs
from converter_generator import next_batch
from converter_generator import random_batch
from model import audio_u_net_dnn
from optimizer import setup_optimizer
from optimizer import learing_rate_scheduling

# Please modify input path  to locate you file
DATASETS_ROOT_DIR = './datasets'
FILE_NAME_LISTS_DIR = os.path.join(DATASETS_ROOT_DIR, 'final_dataset')
OUTPUT_TENSORBOARD_DIR = './output'
OUTPUT_MODEL_DIR = './output/model'

# Please modify setting for training
n_epochs = 10
batch_size = 8
initial_learning_rate = 0.001
decay_factor = 0.01
n_epochs_per_decay = 2

# Check location to save datasets
if not os.path.exists(OUTPUT_TENSORBOARD_DIR):
    os.makedirs(OUTPUT_TENSORBOARD_DIR)
if not os.path.exists(OUTPUT_MODEL_DIR):
    os.makedirs(OUTPUT_MODEL_DIR)

print('-------------------------Begining data input---------------------------')

#############
# DATA IMPORT
#############

train_original_noise_pairs = get_original_noise_pairs(FILE_NAME_LISTS_DIR,
                                                      'train')
val_original_noise_pairs = get_original_noise_pairs(FILE_NAME_LISTS_DIR,
                                                    'validation')

# Selet first original noise pair, return first is bit rate pair and second
# is the waveform pair
br_pair, wf_pair = bitrates_and_waveforms(train_original_noise_pairs[0])

# Get original bit rate and waveform
original_bitrate = br_pair[0]
original_waveform = wf_pair[0]

# reshape for mono waveforms
original_waveform = original_waveform.reshape((-1, 1))

# Number of sample for each epoch train
sample_per_epoch = len(train_original_noise_pairs)

print('Number of epochs: {}'.format(n_epochs))
print('Samples per epoch: {}'.format(sample_per_epoch))
print('Batch size: {}'.format(batch_size))
print('-------------------------Processing training---------------------------')

##################
# MODEL DEFINITION
##################

train_flag, x, y_pred = audio_u_net_dnn(original_waveform.dtype,
                                        original_waveform.shape)

# placeholder for the true waveform
y = tf.placeholder(original_waveform.dtype,
                   shape=x.get_shape(),
                   name='y')

###############
# LOSS FUNCTION
###############

with tf.name_scope('mse'):
    mse = tf.reduce_mean(tf.square(tf.subtract(y_pred, y)))
tf.summary.scalar('mse', mse)

######################
# OPTIMIZATION ROUTINE
######################

# Variable that affect learning rate.
n_batches_per_epoch = float(sample_per_epoch)/ batch_size
decay_steps = int(n_batches_per_epoch * n_epochs_per_decay)

# Decay the learning rate based on the number of steps.
learning_rate, global_step = learing_rate_scheduling(initial_learning_rate,
                                                     decay_steps,
                                                     decay_factor)

# Setup the training operator
min_args = {'global_step': global_step}
training_op = setup_optimizer(learning_rate,
                              mse,
                              tf.train.AdamOptimizer,
                              minimize_args=min_args)

##################
# TRAINING PROCESS
##################

# Add ops to save and restore all the variables.
saver = tf.train.Saver()

# initialize the variables for the session
init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init)
    
    # initialize tensorboard file writers
    merged = tf.summary.merge_all()
    tensorboard_path = os.path.join(OUTPUT_TENSORBOARD_DIR, 'tensorboard')
    train_writer = tf.summary.FileWriter(tensorboard_path, sess.graph)
    model_name = y_pred.name[: 15]
    val_loss_file = open('val_loss_log.txt', 'w')
    train_loss_file = open('train_loss_log.txt', 'w')

    # The number of batchs in each epoch train
    n_batchs = int(sample_per_epoch / batch_size)

    # The number of iteration
    n_iterations = n_epochs * n_batchs

    # Start train loop
    for i in range(n_iterations):
        
        print('The training iterations is: {}'.format(i))
        
        # Random generate next batch in the training file
        train_batch = random_batch(batch_size, train_original_noise_pairs)

        # Setting a flag to cheack iteration go to next epoch
        new_epoch_flag = ((i + 1) % n_batchs == 0)

        # Record epoch number
        if new_epoch_flag:
            epoch_number = int((i + 1) / n_batchs)

        # Start validation if enter new epoch
        if new_epoch_flag:

            print('Calculating validation loss by total {} iterations'.format(
                len(val_original_noise_pairs) / batch_size))

            total_val_loss = 0
            val_count = 0

            # Find each validation loss for same batch size
            for val_batch in next_batch(batch_size, val_original_noise_pairs):
                loss = sess.run([mse],
                                feed_dict={train_flag: False,
                                           x: val_batch[1],
                                           y: val_batch[0]})
                total_val_loss += np.mean(loss)
                val_count += 1

            # Calculate the the average validaton loss
            val_loss = total_val_loss / val_count

            print('Epoch is: {}, Validation Loss is: {}'.format(epoch_number, 
                                                                val_loss))
            
            # Record the average validation loss for each epoch
            val_loss_file.write(
                'Epoch is: {}, Validation Loss is:{}\n'.format(epoch_number, 
                                                               val_loss))

        # Start recording traning loss if enter a new epoch
        if new_epoch_flag:
            summary, _, train_loss = sess.run([merged, training_op, mse],
                                              feed_dict={train_flag: True,
                                                         x: train_batch[1],
                                                         y: train_batch[0]})
                
            print('Epoch is: {}, Training Loss is: {}'.format(epoch_number, 
                                                              train_loss))
                
            train_writer.add_summary(summary, i)
                
            # Record the training loss for each epoch
            train_loss_file.write(
                'Epoch is: {}, Training Loss is: {}\n'.format(epoch_number, 
                                                              train_loss))
                
            # Store the training model every 3 epoch
            if epoch_number % 3 == 0:
                model_path = os.path.join(
                    OUTPUT_MODEL_DIR, '{}_{}.ckpt'.format(model_name, 
                                                          epoch_number))
                save_path = saver.save(sess, model_path)

        # Run tensorflow for each train batch
        sess.run(training_op, 
                 feed_dict={train_flag: True,
                            x: train_batch[1],
                            y: train_batch[0]})

    val_loss_file.close()
    train_loss_file.close()

    # Save the variables to disk.
    model_path = os.path.join(
        OUTPUT_MODEL_DIR, '{}_final.ckpt'.format(model_name))
    save_path = saver.save(sess, model_path)

print("Model checkpoints will be saved in file: {}".format(save_path))
print('------------------------Finished model training------------------------')
# Out:
# -------------------------Begining data input---------------------------
# Number of epochs: 10
# Samples per epoch: 814
# Batch size: 8
# -------------------------Processing training---------------------------
# The network summary for audio_u_net_dnn
#     input: [80000, 1]
#     downsample layer: [39998, 8]
#     downsample layer: [19998, 16]
#     downsample layer: [9998, 32]
#     downsample layer: [4998, 64]
#     downsample layer: [2498, 128]
#     downsample layer: [1248, 256]
#     downsample layer: [623, 512]
#     downsample layer: [311, 1024]
#     bottleneck layer: [154, 2048]
#     upsample layer: [304, 2048]
#     upsample layer: [604, 1024]
#     upsample layer: [1204, 512]
#     upsample layer: [2404, 256]
#     upsample layer: [4804, 128]
#     upsample layer: [9604, 64]
#     upsample layer: [19204, 32]
#     upsample layer: [38404, 16]
#     restack layer: [40002, 15]
#     final convolution layer: [40000, 2]
#     output: [80000, 1]
# --------------------Finished model building--------------------
# The training iterations is: 0
# The training iterations is: 1
# The training iterations is: 2
# The training iterations is: 3
# The training iterations is: 4
# The training iterations is: 5
# The training iterations is: 6
# The training iterations is: 7
# The training iterations is: 8
# The training iterations is: 9
# The training iterations is: 10
# The training iterations is: 11
# The training iterations is: 12
# The training iterations is: 13
# The training iterations is: 14
# The training iterations is: 15
# The training iterations is: 16
# The training iterations is: 17
# The training iterations is: 18
# The training iterations is: 19
# The training iterations is: 20
# The training iterations is: 21
# The training iterations is: 22
# The training iterations is: 23
# The training iterations is: 24
# The training iterations is: 25
# The training iterations is: 26
# The training iterations is: 27
# The training iterations is: 28
# The training iterations is: 29
# The training iterations is: 30
# The training iterations is: 31
# The training iterations is: 32
# The training iterations is: 33
# The training iterations is: 34
# The training iterations is: 35
# The training iterations is: 36
# The training iterations is: 37
# The training iterations is: 38
# The training iterations is: 39
# The training iterations is: 40
# The training iterations is: 41
# The training iterations is: 42
# The training iterations is: 43
# The training iterations is: 44
# The training iterations is: 45
# The training iterations is: 46
# The training iterations is: 47
# The training iterations is: 48
# The training iterations is: 49
# The training iterations is: 50
# The training iterations is: 51
# The training iterations is: 52
# The training iterations is: 53
# The training iterations is: 54
# The training iterations is: 55
# The training iterations is: 56
# The training iterations is: 57
# The training iterations is: 58
# The training iterations is: 59
# The training iterations is: 60
# The training iterations is: 61
# The training iterations is: 62
# The training iterations is: 63
# The training iterations is: 64
# The training iterations is: 65
# The training iterations is: 66
# The training iterations is: 67
# The training iterations is: 68
# The training iterations is: 69
# The training iterations is: 70
# The training iterations is: 71
# The training iterations is: 72
# The training iterations is: 73
# The training iterations is: 74
# The training iterations is: 75
# The training iterations is: 76
# The training iterations is: 77
# The training iterations is: 78
# The training iterations is: 79
# The training iterations is: 80
# The training iterations is: 81
# The training iterations is: 82
# The training iterations is: 83
# The training iterations is: 84
# The training iterations is: 85
# The training iterations is: 86
# The training iterations is: 87
# The training iterations is: 88
# The training iterations is: 89
# The training iterations is: 90
# The training iterations is: 91
# The training iterations is: 92
# The training iterations is: 93
# The training iterations is: 94
# The training iterations is: 95
# The training iterations is: 96
# The training iterations is: 97
# The training iterations is: 98
# The training iterations is: 99
# The training iterations is: 100
# Calculating validation loss by total 20.25 iterations
# Epoch is: 1, Validation Loss is: 0.007140172257398565
# Epoch is: 1, Training Loss is: 0.004042102489620447
# The training iterations is: 101
# The training iterations is: 102
# The training iterations is: 103
# The training iterations is: 104
# The training iterations is: 105
# The training iterations is: 106
# The training iterations is: 107
# The training iterations is: 108
# The training iterations is: 109
# The training iterations is: 110
# The training iterations is: 111
# The training iterations is: 112
# The training iterations is: 113
# The training iterations is: 114
# The training iterations is: 115
# The training iterations is: 116
# The training iterations is: 117
# The training iterations is: 118
# The training iterations is: 119
# The training iterations is: 120
# The training iterations is: 121
# The training iterations is: 122
# The training iterations is: 123
# The training iterations is: 124
# The training iterations is: 125
# The training iterations is: 126
# The training iterations is: 127
# The training iterations is: 128
# The training iterations is: 129
# The training iterations is: 130
# The training iterations is: 131
# The training iterations is: 132
# The training iterations is: 133
# The training iterations is: 134
# The training iterations is: 135
# The training iterations is: 136
# The training iterations is: 137
# The training iterations is: 138
# The training iterations is: 139
# The training iterations is: 140
# The training iterations is: 141
# The training iterations is: 142
# The training iterations is: 143
# The training iterations is: 144
# The training iterations is: 145
# The training iterations is: 146
# The training iterations is: 147
# The training iterations is: 148
# The training iterations is: 149
# The training iterations is: 150
# The training iterations is: 151
# The training iterations is: 152
# The training iterations is: 153
# The training iterations is: 154
# The training iterations is: 155
# The training iterations is: 156
# The training iterations is: 157
# The training iterations is: 158
# The training iterations is: 159
# The training iterations is: 160
# The training iterations is: 161
# The training iterations is: 162
# The training iterations is: 163
# The training iterations is: 164
# The training iterations is: 165
# The training iterations is: 166
# The training iterations is: 167
# The training iterations is: 168
# The training iterations is: 169
# The training iterations is: 170
# The training iterations is: 171
# The training iterations is: 172
# The training iterations is: 173
# The training iterations is: 174
# The training iterations is: 175
# The training iterations is: 176
# The training iterations is: 177
# The training iterations is: 178
# The training iterations is: 179
# The training iterations is: 180
# The training iterations is: 181
# The training iterations is: 182
# The training iterations is: 183
# The training iterations is: 184
# The training iterations is: 185
# The training iterations is: 186
# The training iterations is: 187
# The training iterations is: 188
# The training iterations is: 189
# The training iterations is: 190
# The training iterations is: 191
# The training iterations is: 192
# The training iterations is: 193
# The training iterations is: 194
# The training iterations is: 195
# The training iterations is: 196
# The training iterations is: 197
# The training iterations is: 198
# The training iterations is: 199
# The training iterations is: 200
# The training iterations is: 201
# Calculating validation loss by total 20.25 iterations
# Epoch is: 2, Validation Loss is: 0.006073700807367762
# Epoch is: 2, Training Loss is: 0.006620047613978386
# The training iterations is: 202
# The training iterations is: 203
# The training iterations is: 204
# The training iterations is: 205
# The training iterations is: 206
# The training iterations is: 207
# The training iterations is: 208
# The training iterations is: 209
# The training iterations is: 210
# The training iterations is: 211
# The training iterations is: 212
# The training iterations is: 213
# The training iterations is: 214
# The training iterations is: 215
# The training iterations is: 216
# The training iterations is: 217
# The training iterations is: 218
# The training iterations is: 219
# The training iterations is: 220
# The training iterations is: 221
# The training iterations is: 222
# The training iterations is: 223
# The training iterations is: 224
# The training iterations is: 225
# The training iterations is: 226
# The training iterations is: 227
# The training iterations is: 228
# The training iterations is: 229
# The training iterations is: 230
# The training iterations is: 231
# The training iterations is: 232
# The training iterations is: 233
# The training iterations is: 234
# The training iterations is: 235
# The training iterations is: 236
# The training iterations is: 237
# The training iterations is: 238
# The training iterations is: 239
# The training iterations is: 240
# The training iterations is: 241
# The training iterations is: 242
# The training iterations is: 243
# The training iterations is: 244
# The training iterations is: 245
# The training iterations is: 246
# The training iterations is: 247
# The training iterations is: 248
# The training iterations is: 249
# The training iterations is: 250
# The training iterations is: 251
# The training iterations is: 252
# The training iterations is: 253
# The training iterations is: 254
# The training iterations is: 255
# The training iterations is: 256
# The training iterations is: 257
# The training iterations is: 258
# The training iterations is: 259
# The training iterations is: 260
# The training iterations is: 261
# The training iterations is: 262
# The training iterations is: 263
# The training iterations is: 264
# The training iterations is: 265
# The training iterations is: 266
# The training iterations is: 267
# The training iterations is: 268
# The training iterations is: 269
# The training iterations is: 270
# The training iterations is: 271
# The training iterations is: 272
# The training iterations is: 273
# The training iterations is: 274
# The training iterations is: 275
# The training iterations is: 276
# The training iterations is: 277
# The training iterations is: 278
# The training iterations is: 279
# The training iterations is: 280
# The training iterations is: 281
# The training iterations is: 282
# The training iterations is: 283
# The training iterations is: 284
# The training iterations is: 285
# The training iterations is: 286
# The training iterations is: 287
# The training iterations is: 288
# The training iterations is: 289
# The training iterations is: 290
# The training iterations is: 291
# The training iterations is: 292
# The training iterations is: 293
# The training iterations is: 294
# The training iterations is: 295
# The training iterations is: 296
# The training iterations is: 297
# The training iterations is: 298
# The training iterations is: 299
# The training iterations is: 300
# The training iterations is: 301
# The training iterations is: 302
# Calculating validation loss by total 20.25 iterations
# Epoch is: 3, Validation Loss is: 0.0058538159688136405
# Epoch is: 3, Training Loss is: 0.003292467212304473
# The training iterations is: 303
# The training iterations is: 304
# The training iterations is: 305
# The training iterations is: 306
# The training iterations is: 307
# The training iterations is: 308
# The training iterations is: 309
# The training iterations is: 310
# The training iterations is: 311
# The training iterations is: 312
# The training iterations is: 313
# The training iterations is: 314
# The training iterations is: 315
# The training iterations is: 316
# The training iterations is: 317
# The training iterations is: 318
# The training iterations is: 319
# The training iterations is: 320
# The training iterations is: 321
# The training iterations is: 322
# The training iterations is: 323
# The training iterations is: 324
# The training iterations is: 325
# The training iterations is: 326
# The training iterations is: 327
# The training iterations is: 328
# The training iterations is: 329
# The training iterations is: 330
# The training iterations is: 331
# The training iterations is: 332
# The training iterations is: 333
# The training iterations is: 334
# The training iterations is: 335
# The training iterations is: 336
# The training iterations is: 337
# The training iterations is: 338
# The training iterations is: 339
# The training iterations is: 340
# The training iterations is: 341
# The training iterations is: 342
# The training iterations is: 343
# The training iterations is: 344
# The training iterations is: 345
# The training iterations is: 346
# The training iterations is: 347
# The training iterations is: 348
# The training iterations is: 349
# The training iterations is: 350
# The training iterations is: 351
# The training iterations is: 352
# The training iterations is: 353
# The training iterations is: 354
# The training iterations is: 355
# The training iterations is: 356
# The training iterations is: 357
# The training iterations is: 358
# The training iterations is: 359
# The training iterations is: 360
# The training iterations is: 361
# The training iterations is: 362
# The training iterations is: 363
# The training iterations is: 364
# The training iterations is: 365
# The training iterations is: 366
# The training iterations is: 367
# The training iterations is: 368
# The training iterations is: 369
# The training iterations is: 370
# The training iterations is: 371
# The training iterations is: 372
# The training iterations is: 373
# The training iterations is: 374
# The training iterations is: 375
# The training iterations is: 376
# The training iterations is: 377
# The training iterations is: 378
# The training iterations is: 379
# The training iterations is: 380
# The training iterations is: 381
# The training iterations is: 382
# The training iterations is: 383
# The training iterations is: 384
# The training iterations is: 385
# The training iterations is: 386
# The training iterations is: 387
# The training iterations is: 388
# The training iterations is: 389
# The training iterations is: 390
# The training iterations is: 391
# The training iterations is: 392
# The training iterations is: 393
# The training iterations is: 394
# The training iterations is: 395
# The training iterations is: 396
# The training iterations is: 397
# The training iterations is: 398
# The training iterations is: 399
# The training iterations is: 400
# The training iterations is: 401
# The training iterations is: 402
# The training iterations is: 403
# Calculating validation loss by total 20.25 iterations
# Epoch is: 4, Validation Loss is: 0.0055461537115098465
# Epoch is: 4, Training Loss is: 0.0027231131680309772
# The training iterations is: 404
# The training iterations is: 405
# The training iterations is: 406
# The training iterations is: 407
# The training iterations is: 408
# The training iterations is: 409
# The training iterations is: 410
# The training iterations is: 411
# The training iterations is: 412
# The training iterations is: 413
# The training iterations is: 414
# The training iterations is: 415
# The training iterations is: 416
# The training iterations is: 417
# The training iterations is: 418
# The training iterations is: 419
# The training iterations is: 420
# The training iterations is: 421
# The training iterations is: 422
# The training iterations is: 423
# The training iterations is: 424
# The training iterations is: 425
# The training iterations is: 426
# The training iterations is: 427
# The training iterations is: 428
# The training iterations is: 429
# The training iterations is: 430
# The training iterations is: 431
# The training iterations is: 432
# The training iterations is: 433
# The training iterations is: 434
# The training iterations is: 435
# The training iterations is: 436
# The training iterations is: 437
# The training iterations is: 438
# The training iterations is: 439
# The training iterations is: 440
# The training iterations is: 441
# The training iterations is: 442
# The training iterations is: 443
# The training iterations is: 444
# The training iterations is: 445
# The training iterations is: 446
# The training iterations is: 447
# The training iterations is: 448
# The training iterations is: 449
# The training iterations is: 450
# The training iterations is: 451
# The training iterations is: 452
# The training iterations is: 453
# The training iterations is: 454
# The training iterations is: 455
# The training iterations is: 456
# The training iterations is: 457
# The training iterations is: 458
# The training iterations is: 459
# The training iterations is: 460
# The training iterations is: 461
# The training iterations is: 462
# The training iterations is: 463
# The training iterations is: 464
# The training iterations is: 465
# The training iterations is: 466
# The training iterations is: 467
# The training iterations is: 468
# The training iterations is: 469
# The training iterations is: 470
# The training iterations is: 471
# The training iterations is: 472
# The training iterations is: 473
# The training iterations is: 474
# The training iterations is: 475
# The training iterations is: 476
# The training iterations is: 477
# The training iterations is: 478
# The training iterations is: 479
# The training iterations is: 480
# The training iterations is: 481
# The training iterations is: 482
# The training iterations is: 483
# The training iterations is: 484
# The training iterations is: 485
# The training iterations is: 486
# The training iterations is: 487
# The training iterations is: 488
# The training iterations is: 489
# The training iterations is: 490
# The training iterations is: 491
# The training iterations is: 492
# The training iterations is: 493
# The training iterations is: 494
# The training iterations is: 495
# The training iterations is: 496
# The training iterations is: 497
# The training iterations is: 498
# The training iterations is: 499
# The training iterations is: 500
# The training iterations is: 501
# The training iterations is: 502
# The training iterations is: 503
# The training iterations is: 504
# Calculating validation loss by total 20.25 iterations
# Epoch is: 5, Validation Loss is: 0.005130296495432655
# Epoch is: 5, Training Loss is: 0.004093754570931196
# The training iterations is: 505
# The training iterations is: 506
# The training iterations is: 507
# The training iterations is: 508
# The training iterations is: 509
# The training iterations is: 510
# The training iterations is: 511
# The training iterations is: 512
# The training iterations is: 513
# The training iterations is: 514
# The training iterations is: 515
# The training iterations is: 516
# The training iterations is: 517
# The training iterations is: 518
# The training iterations is: 519
# The training iterations is: 520
# The training iterations is: 521
# The training iterations is: 522
# The training iterations is: 523
# The training iterations is: 524
# The training iterations is: 525
# The training iterations is: 526
# The training iterations is: 527
# The training iterations is: 528
# The training iterations is: 529
# The training iterations is: 530
# The training iterations is: 531
# The training iterations is: 532
# The training iterations is: 533
# The training iterations is: 534
# The training iterations is: 535
# The training iterations is: 536
# The training iterations is: 537
# The training iterations is: 538
# The training iterations is: 539
# The training iterations is: 540
# The training iterations is: 541
# The training iterations is: 542
# The training iterations is: 543
# The training iterations is: 544
# The training iterations is: 545
# The training iterations is: 546
# The training iterations is: 547
# The training iterations is: 548
# The training iterations is: 549
# The training iterations is: 550
# The training iterations is: 551
# The training iterations is: 552
# The training iterations is: 553
# The training iterations is: 554
# The training iterations is: 555
# The training iterations is: 556
# The training iterations is: 557
# The training iterations is: 558
# The training iterations is: 559
# The training iterations is: 560
# The training iterations is: 561
# The training iterations is: 562
# The training iterations is: 563
# The training iterations is: 564
# The training iterations is: 565
# The training iterations is: 566
# The training iterations is: 567
# The training iterations is: 568
# The training iterations is: 569
# The training iterations is: 570
# The training iterations is: 571
# The training iterations is: 572
# The training iterations is: 573
# The training iterations is: 574
# The training iterations is: 575
# The training iterations is: 576
# The training iterations is: 577
# The training iterations is: 578
# The training iterations is: 579
# The training iterations is: 580
# The training iterations is: 581
# The training iterations is: 582
# The training iterations is: 583
# The training iterations is: 584
# The training iterations is: 585
# The training iterations is: 586
# The training iterations is: 587
# The training iterations is: 588
# The training iterations is: 589
# The training iterations is: 590
# The training iterations is: 591
# The training iterations is: 592
# The training iterations is: 593
# The training iterations is: 594
# The training iterations is: 595
# The training iterations is: 596
# The training iterations is: 597
# The training iterations is: 598
# The training iterations is: 599
# The training iterations is: 600
# The training iterations is: 601
# The training iterations is: 602
# The training iterations is: 603
# The training iterations is: 604
# The training iterations is: 605
# Calculating validation loss by total 20.25 iterations
# Epoch is: 6, Validation Loss is: 0.0047339939933625005
# Epoch is: 6, Training Loss is: 0.0037102974019944668
# The training iterations is: 606
# The training iterations is: 607
# The training iterations is: 608
# The training iterations is: 609
# The training iterations is: 610
# The training iterations is: 611
# The training iterations is: 612
# The training iterations is: 613
# The training iterations is: 614
# The training iterations is: 615
# The training iterations is: 616
# The training iterations is: 617
# The training iterations is: 618
# The training iterations is: 619
# The training iterations is: 620
# The training iterations is: 621
# The training iterations is: 622
# The training iterations is: 623
# The training iterations is: 624
# The training iterations is: 625
# The training iterations is: 626
# The training iterations is: 627
# The training iterations is: 628
# The training iterations is: 629
# The training iterations is: 630
# The training iterations is: 631
# The training iterations is: 632
# The training iterations is: 633
# The training iterations is: 634
# The training iterations is: 635
# The training iterations is: 636
# The training iterations is: 637
# The training iterations is: 638
# The training iterations is: 639
# The training iterations is: 640
# The training iterations is: 641
# The training iterations is: 642
# The training iterations is: 643
# The training iterations is: 644
# The training iterations is: 645
# The training iterations is: 646
# The training iterations is: 647
# The training iterations is: 648
# The training iterations is: 649
# The training iterations is: 650
# The training iterations is: 651
# The training iterations is: 652
# The training iterations is: 653
# The training iterations is: 654
# The training iterations is: 655
# The training iterations is: 656
# The training iterations is: 657
# The training iterations is: 658
# The training iterations is: 659
# The training iterations is: 660
# The training iterations is: 661
# The training iterations is: 662
# The training iterations is: 663
# The training iterations is: 664
# The training iterations is: 665
# The training iterations is: 666
# The training iterations is: 667
# The training iterations is: 668
# The training iterations is: 669
# The training iterations is: 670
# The training iterations is: 671
# The training iterations is: 672
# The training iterations is: 673
# The training iterations is: 674
# The training iterations is: 675
# The training iterations is: 676
# The training iterations is: 677
# The training iterations is: 678
# The training iterations is: 679
# The training iterations is: 680
# The training iterations is: 681
# The training iterations is: 682
# The training iterations is: 683
# The training iterations is: 684
# The training iterations is: 685
# The training iterations is: 686
# The training iterations is: 687
# The training iterations is: 688
# The training iterations is: 689
# The training iterations is: 690
# The training iterations is: 691
# The training iterations is: 692
# The training iterations is: 693
# The training iterations is: 694
# The training iterations is: 695
# The training iterations is: 696
# The training iterations is: 697
# The training iterations is: 698
# The training iterations is: 699
# The training iterations is: 700
# The training iterations is: 701
# The training iterations is: 702
# The training iterations is: 703
# The training iterations is: 704
# The training iterations is: 705
# The training iterations is: 706
# Calculating validation loss by total 20.25 iterations
# Epoch is: 7, Validation Loss is: 0.004530680853696097
# Epoch is: 7, Training Loss is: 0.007999632507562637
# The training iterations is: 707
# The training iterations is: 708
# The training iterations is: 709
# The training iterations is: 710
# The training iterations is: 711
# The training iterations is: 712
# The training iterations is: 713
# The training iterations is: 714
# The training iterations is: 715
# The training iterations is: 716
# The training iterations is: 717
# The training iterations is: 718
# The training iterations is: 719
# The training iterations is: 720
# The training iterations is: 721
# The training iterations is: 722
# The training iterations is: 723
# The training iterations is: 724
# The training iterations is: 725
# The training iterations is: 726
# The training iterations is: 727
# The training iterations is: 728
# The training iterations is: 729
# The training iterations is: 730
# The training iterations is: 731
# The training iterations is: 732
# The training iterations is: 733
# The training iterations is: 734
# The training iterations is: 735
# The training iterations is: 736
# The training iterations is: 737
# The training iterations is: 738
# The training iterations is: 739
# The training iterations is: 740
# The training iterations is: 741
# The training iterations is: 742
# The training iterations is: 743
# The training iterations is: 744
# The training iterations is: 745
# The training iterations is: 746
# The training iterations is: 747
# The training iterations is: 748
# The training iterations is: 749
# The training iterations is: 750
# The training iterations is: 751
# The training iterations is: 752
# The training iterations is: 753
# The training iterations is: 754
# The training iterations is: 755
# The training iterations is: 756
# The training iterations is: 757
# The training iterations is: 758
# The training iterations is: 759
# The training iterations is: 760
# The training iterations is: 761
# The training iterations is: 762
# The training iterations is: 763
# The training iterations is: 764
# The training iterations is: 765
# The training iterations is: 766
# The training iterations is: 767
# The training iterations is: 768
# The training iterations is: 769
# The training iterations is: 770
# The training iterations is: 771
# The training iterations is: 772
# The training iterations is: 773
# The training iterations is: 774
# The training iterations is: 775
# The training iterations is: 776
# The training iterations is: 777
# The training iterations is: 778
# The training iterations is: 779
# The training iterations is: 780
# The training iterations is: 781
# The training iterations is: 782
# The training iterations is: 783
# The training iterations is: 784
# The training iterations is: 785
# The training iterations is: 786
# The training iterations is: 787
# The training iterations is: 788
# The training iterations is: 789
# The training iterations is: 790
# The training iterations is: 791
# The training iterations is: 792
# The training iterations is: 793
# The training iterations is: 794
# The training iterations is: 795
# The training iterations is: 796
# The training iterations is: 797
# The training iterations is: 798
# The training iterations is: 799
# The training iterations is: 800
# The training iterations is: 801
# The training iterations is: 802
# The training iterations is: 803
# The training iterations is: 804
# The training iterations is: 805
# The training iterations is: 806
# The training iterations is: 807
# Calculating validation loss by total 20.25 iterations
# Epoch is: 8, Validation Loss is: 0.004391149573382877
# Epoch is: 8, Training Loss is: 0.004603357054293156
# The training iterations is: 808
# The training iterations is: 809
# The training iterations is: 810
# The training iterations is: 811
# The training iterations is: 812
# The training iterations is: 813
# The training iterations is: 814
# The training iterations is: 815
# The training iterations is: 816
# The training iterations is: 817
# The training iterations is: 818
# The training iterations is: 819
# The training iterations is: 820
# The training iterations is: 821
# The training iterations is: 822
# The training iterations is: 823
# The training iterations is: 824
# The training iterations is: 825
# The training iterations is: 826
# The training iterations is: 827
# The training iterations is: 828
# The training iterations is: 829
# The training iterations is: 830
# The training iterations is: 831
# The training iterations is: 832
# The training iterations is: 833
# The training iterations is: 834
# The training iterations is: 835
# The training iterations is: 836
# The training iterations is: 837
# The training iterations is: 838
# The training iterations is: 839
# The training iterations is: 840
# The training iterations is: 841
# The training iterations is: 842
# The training iterations is: 843
# The training iterations is: 844
# The training iterations is: 845
# The training iterations is: 846
# The training iterations is: 847
# The training iterations is: 848
# The training iterations is: 849
# The training iterations is: 850
# The training iterations is: 851
# The training iterations is: 852
# The training iterations is: 853
# The training iterations is: 854
# The training iterations is: 855
# The training iterations is: 856
# The training iterations is: 857
# The training iterations is: 858
# The training iterations is: 859
# The training iterations is: 860
# The training iterations is: 861
# The training iterations is: 862
# The training iterations is: 863
# The training iterations is: 864
# The training iterations is: 865
# The training iterations is: 866
# The training iterations is: 867
# The training iterations is: 868
# The training iterations is: 869
# The training iterations is: 870
# The training iterations is: 871
# The training iterations is: 872
# The training iterations is: 873
# The training iterations is: 874
# The training iterations is: 875
# The training iterations is: 876
# The training iterations is: 877
# The training iterations is: 878
# The training iterations is: 879
# The training iterations is: 880
# The training iterations is: 881
# The training iterations is: 882
# The training iterations is: 883
# The training iterations is: 884
# The training iterations is: 885
# The training iterations is: 886
# The training iterations is: 887
# The training iterations is: 888
# The training iterations is: 889
# The training iterations is: 890
# The training iterations is: 891
# The training iterations is: 892
# The training iterations is: 893
# The training iterations is: 894
# The training iterations is: 895
# The training iterations is: 896
# The training iterations is: 897
# The training iterations is: 898
# The training iterations is: 899
# The training iterations is: 900
# The training iterations is: 901
# The training iterations is: 902
# The training iterations is: 903
# The training iterations is: 904
# The training iterations is: 905
# The training iterations is: 906
# The training iterations is: 907
# The training iterations is: 908
# Calculating validation loss by total 20.25 iterations
# Epoch is: 9, Validation Loss is: 0.004575016176594155
# Epoch is: 9, Training Loss is: 0.0031764612067490816
# The training iterations is: 909
# The training iterations is: 910
# The training iterations is: 911
# The training iterations is: 912
# The training iterations is: 913
# The training iterations is: 914
# The training iterations is: 915
# The training iterations is: 916
# The training iterations is: 917
# The training iterations is: 918
# The training iterations is: 919
# The training iterations is: 920
# The training iterations is: 921
# The training iterations is: 922
# The training iterations is: 923
# The training iterations is: 924
# The training iterations is: 925
# The training iterations is: 926
# The training iterations is: 927
# The training iterations is: 928
# The training iterations is: 929
# The training iterations is: 930
# The training iterations is: 931
# The training iterations is: 932
# The training iterations is: 933
# The training iterations is: 934
# The training iterations is: 935
# The training iterations is: 936
# The training iterations is: 937
# The training iterations is: 938
# The training iterations is: 939
# The training iterations is: 940
# The training iterations is: 941
# The training iterations is: 942
# The training iterations is: 943
# The training iterations is: 944
# The training iterations is: 945
# The training iterations is: 946
# The training iterations is: 947
# The training iterations is: 948
# The training iterations is: 949
# The training iterations is: 950
# The training iterations is: 951
# The training iterations is: 952
# The training iterations is: 953
# The training iterations is: 954
# The training iterations is: 955
# The training iterations is: 956
# The training iterations is: 957
# The training iterations is: 958
# The training iterations is: 959
# The training iterations is: 960
# The training iterations is: 961
# The training iterations is: 962
# The training iterations is: 963
# The training iterations is: 964
# The training iterations is: 965
# The training iterations is: 966
# The training iterations is: 967
# The training iterations is: 968
# The training iterations is: 969
# The training iterations is: 970
# The training iterations is: 971
# The training iterations is: 972
# The training iterations is: 973
# The training iterations is: 974
# The training iterations is: 975
# The training iterations is: 976
# The training iterations is: 977
# The training iterations is: 978
# The training iterations is: 979
# The training iterations is: 980
# The training iterations is: 981
# The training iterations is: 982
# The training iterations is: 983
# The training iterations is: 984
# The training iterations is: 985
# The training iterations is: 986
# The training iterations is: 987
# The training iterations is: 988
# The training iterations is: 989
# The training iterations is: 990
# The training iterations is: 991
# The training iterations is: 992
# The training iterations is: 993
# The training iterations is: 994
# The training iterations is: 995
# The training iterations is: 996
# The training iterations is: 997
# The training iterations is: 998
# The training iterations is: 999
# The training iterations is: 1000
# The training iterations is: 1001
# The training iterations is: 1002
# The training iterations is: 1003
# The training iterations is: 1004
# The training iterations is: 1005
# The training iterations is: 1006
# The training iterations is: 1007
# The training iterations is: 1008
# The training iterations is: 1009
# Calculating validation loss by total 20.25 iterations
# Epoch is: 10, Validation Loss is: 0.0042612131551972455
# Epoch is: 10, Training Loss is: 0.0027015646919608116
# Model checkpoints will be saved in file: ./output/model/audio_u_net_dnn_final.ckpt
# ------------------------Finished model training------------------------
